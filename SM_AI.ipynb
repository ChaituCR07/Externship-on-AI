# %% [markdown]
# #Basic Python

# %%
#variable
a = 12

# %%
# '\' continues code for next line
a = 10+12\
-11\
+1
print(a)
# Out:
# 12

# %%
# Data type
# Numeric type

var1 = 10
var2 = 10.12
var3 = 10+2J

print(type(var1))
print(type(var2))
print(type(var3))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
print("Variable var1 data type is"+str(type(var1)))
# Out:
# Variable var1 data type is<class 'int'>

# %%
# Sequence Type
# List

list1 = [1,2,2,4, 'Chaitu',12.33,12+4J]
list1
# Out:
# [1, 2, 2, 4, 'Chaitu', 12.33, (12+4j)]

# %%
list1[2] #positive Index
# Out:
# 2

# %%
list1[-2] #negative Index
# Out:
# 12.33

# %%
list1[0:4] #positive slicing
# Out:
# [1, 2, 2, 4]

# %%
list1[-4:-2] #negative slicing
# Out:
# [4, 'Chaitu']

# %%
# Mutable
list1[0] = "Hello"
list1
# Out:
# ['Hello', 2, 2, 4, 'Chaitu', 12.33, (12+4j)]

# %%
tup = (1,2,3,'hari')
tup
#tuples are not callable we cant use the slicing option in tuples
# Out:
# (1, 2, 3, 'hari')

# %%
# Set 
st = {1,2,'new','old',12.22,'new'}
st
# Out:
# {1, 12.22, 2, 'new', 'old'}
